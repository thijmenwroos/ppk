# %%
import os
import pandas as pd

# from papyrus_scripts.download import download_papyrus

# %%
df = pd.read_csv('/home/s2861704/ppk/test_kin/papyrus_data/kinase-modelling/kinase200_noCMF.csv', sep=',')
display(df)
# Out:
# /tmp/ipykernel_1948194/912135552.py:1: DtypeWarning: Columns (18,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/home/s2861704/ppk/test_kin/papyrus_data/kinase-modelling/kinase200_noCMF.csv', sep=',')
#                         Activity_ID Quality      source  \
# 0       AAACBXVBBDAYRQ_on_Q5S007_WT    High    ChEMBL34
# 1       AAACGYYPWMUUFL_on_O75116_WT    High  Sharma2016
# 2       AAARUSQRQGITCF_on_P50750_WT    High    ChEMBL34
# 3       AAARUSQRQGITCF_on_Q13627_WT    High    ChEMBL34
# 4       AAAVVDAKZZKRGS_on_P06239_WT    High    ChEMBL34
# ...                             ...     ...         ...
# 119736  ZZAZKOOJVIBTOP_on_P00533_WT    High  Sharma2016
# 119737  ZZHSWTUBYRXXCU_on_O75116_WT    High    ChEMBL34
# 119738  ZZOWQPSBJUXHCA_on_O75116_WT    High  Sharma2016
# 119739  ZZQHNBGRWRQWFI_on_P00533_WT    High  Sharma2016
# 119740  ZZUQPSUYBUDXHW_on_Q16539_WT    High    ChEMBL34
#
# ...

# %%
# filtered_df=df[df['source']!= 'Christmann2016']
# display(filtered_df)

# %%
specified_df=df[df['Classification'].str.contains('TK protein kinase group')]
display(specified_df)
# Out:
#                         Activity_ID Quality      source  \
# 4       AAAVVDAKZZKRGS_on_P06239_WT    High    ChEMBL34
# 5       AAAVVDAKZZKRGS_on_Q06187_WT    High    ChEMBL34
# 12      AACFRJDPYQPXPD_on_P12931_WT    High    ChEMBL34
# 19      AADXSEVDTNPICQ_on_Q16288_WT    High    ChEMBL34
# 25      AAEPFBULPJOZCS_on_P00533_WT    High  Sharma2016
# ...                             ...     ...         ...
# 119725  ZWXBOUXHSQCYIY_on_P00533_WT    High    ChEMBL34
# 119728  ZXILYRWRAKLTOG_on_P00533_WT    High  Sharma2016
# 119734  ZYQMWLIENUFZCY_on_P00533_WT    High    ChEMBL34
# 119736  ZZAZKOOJVIBTOP_on_P00533_WT    High  Sharma2016
# 119739  ZZQHNBGRWRQWFI_on_P00533_WT    High  Sharma2016
#
#                                                       CID  \
# 4                                    ChEMBL:CHEMBL4079354
# 5                                    ChEMBL:CHEMBL4079354
# 12                                    ChEMBL:CHEMBL255522
# ...

# %%
# TK_df=specified_df[specified_df['Classification'].str.contains('TK protein kinase group')]
# CMGC_df=specified_df[specified_df['Classification'].str.contains('CMGC protein kinase group')]
# TK_df = df_new
# display(TK_df)

# %%
specified_df.to_csv(path_or_buf='/home/s2861704/ppk/test_kin/prep_storage/K200_noCMF_TK.csv', sep=',', index=False)

# %%
test_df=pd.read_csv('/home/s2861704/ppk/test_kin/prep_storage/K200_noCMF_TK.csv', sep=',')
display(test_df)
# Out:
#                        Activity_ID Quality      source  \
# 0      AAAVVDAKZZKRGS_on_P06239_WT    High    ChEMBL34
# 1      AAAVVDAKZZKRGS_on_Q06187_WT    High    ChEMBL34
# 2      AACFRJDPYQPXPD_on_P12931_WT    High    ChEMBL34
# 3      AADXSEVDTNPICQ_on_Q16288_WT    High    ChEMBL34
# 4      AAEPFBULPJOZCS_on_P00533_WT    High  Sharma2016
# ...                            ...     ...         ...
# 55055  ZWXBOUXHSQCYIY_on_P00533_WT    High    ChEMBL34
# 55056  ZXILYRWRAKLTOG_on_P00533_WT    High  Sharma2016
# 55057  ZYQMWLIENUFZCY_on_P00533_WT    High    ChEMBL34
# 55058  ZZAZKOOJVIBTOP_on_P00533_WT    High  Sharma2016
# 55059  ZZQHNBGRWRQWFI_on_P00533_WT    High  Sharma2016
#
#                                                      CID  \
# 0                                   ChEMBL:CHEMBL4079354
# 1                                   ChEMBL:CHEMBL4079354
# 2                                    ChEMBL:CHEMBL255522
# 3                                   ChEMBL:CHEMBL5198838
# ...

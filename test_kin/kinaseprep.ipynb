# %%
import os
import pandas as pd

from papyrus_scripts.download import download_papyrus

# %%
df = pd.read_csv('/home/s2861704/ppk/test_kin/papyrus_data/kinase-modelling/kinase1000.csv', sep=',')
display(df)
# Out:
# /tmp/ipykernel_1809812/3297472393.py:1: DtypeWarning: Columns (18,19,20,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/home/s2861704/ppk/test_kin/papyrus_data/kinase-modelling/kinase1000.csv', sep=',')
#                         Activity_ID Quality                          source  \
# 0       AAAAZQPHATYWOK_on_P00533_WT    High  ChEMBL31;Sharma2016;Sharma2016
# 1       AAEPFBULPJOZCS_on_P00533_WT    High                      Sharma2016
# 2       AAFHSECTTHOVFV_on_P00533_WT    High                      Sharma2016
# 3       AAGKMGNYUYCEPD_on_P00533_WT    High                        ChEMBL31
# 4       AAHKGRWRYBCWDL_on_P00533_WT    High                      Sharma2016
# ...                             ...     ...                             ...
# 137957  ZZXFFCMCDXONOF_on_Q9P1W9_WT    High                        ChEMBL31
# 137958  ZZXUNAFAKNKXFW_on_P00533_WT    High                  Christmann2016
# ...

# %%
filtered_df=df[df['source']!= 'Christmann2016']
display(filtered_df)
# Out:
#                         Activity_ID Quality                          source  \
# 0       AAAAZQPHATYWOK_on_P00533_WT    High  ChEMBL31;Sharma2016;Sharma2016
# 1       AAEPFBULPJOZCS_on_P00533_WT    High                      Sharma2016
# 2       AAFHSECTTHOVFV_on_P00533_WT    High                      Sharma2016
# 3       AAGKMGNYUYCEPD_on_P00533_WT    High                        ChEMBL31
# 4       AAHKGRWRYBCWDL_on_P00533_WT    High                      Sharma2016
# ...                             ...     ...                             ...
# 137956  ZZTZDQWPNDXJLO_on_P07333_WT    High                        ChEMBL31
# 137957  ZZXFFCMCDXONOF_on_Q9P1W9_WT    High                        ChEMBL31
# 137959  ZZYCYTFKFSOZMZ_on_P17948_WT    High                        ChEMBL31
# 137960  ZZYCYTFKFSOZMZ_on_P35968_WT    High                        ChEMBL31
# 137961  ZZZJRULMCGMYRH_on_Q16539_WT    High                        ChEMBL31
#
#                                             CID  \
# ...

# %%
specified_df=filtered_df[filtered_df['Classification'].str.contains('CMGC protein kinase group|TK protein kinase group')]
display(specified_df)
# Out:
#                         Activity_ID Quality                          source  \
# 0       AAAAZQPHATYWOK_on_P00533_WT    High  ChEMBL31;Sharma2016;Sharma2016
# 1       AAEPFBULPJOZCS_on_P00533_WT    High                      Sharma2016
# 2       AAFHSECTTHOVFV_on_P00533_WT    High                      Sharma2016
# 3       AAGKMGNYUYCEPD_on_P00533_WT    High                        ChEMBL31
# 4       AAHKGRWRYBCWDL_on_P00533_WT    High                      Sharma2016
# ...                             ...     ...                             ...
# 137955  ZZTQCYMMWZGIOL_on_Q06187_WT    High                        ChEMBL31
# 137956  ZZTZDQWPNDXJLO_on_P07333_WT    High                        ChEMBL31
# 137959  ZZYCYTFKFSOZMZ_on_P17948_WT    High                        ChEMBL31
# 137960  ZZYCYTFKFSOZMZ_on_P35968_WT    High                        ChEMBL31
# 137961  ZZZJRULMCGMYRH_on_Q16539_WT    High                        ChEMBL31
#
#                                             CID  \
# ...

# %%
TK_df=specified_df[specified_df['Classification'].str.contains('TK protein kinase group')]
CMGC_df=specified_df[specified_df['Classification'].str.contains('CMGC protein kinase group')]
display(CMGC_df)
# Out:
#                         Activity_ID Quality      source  \
# 4078    ABQHNCIRSWSJQW_on_P28482_WT    High    ChEMBL31
# 4079    ABTYOLPYCNKOPC_on_P28482_WT    High    ChEMBL31
# 4080    ACXBLBWLPVCGQU_on_P28482_WT    High    ChEMBL31
# 4081    ACXDOBWOZOFUFD_on_P28482_WT    High    ChEMBL31
# 4082    ADEGUVDUVJCDNZ_on_P28482_WT    High    ChEMBL31
# ...                             ...     ...         ...
# 137843  ZZAALKZEEDABCI_on_Q16539_WT    High    ChEMBL31
# 137891  ZZPQBANVXDRDLD_on_P24941_WT    High  Sharma2016
# 137893  ZZRDSHKJUCIYQL_on_P49840_WT    High    ChEMBL31
# 137894  ZZRDSHKJUCIYQL_on_P49841_WT    High    ChEMBL31
# 137961  ZZZJRULMCGMYRH_on_Q16539_WT    High    ChEMBL31
#
#                              CID  \
# 4078    ChEMBL31.compound.348139
# 4079    ChEMBL31.compound.309042
# 4080    ChEMBL31.compound.347820
# 4081    ChEMBL31.compound.431311
# 4082    ChEMBL31.compound.348060
# ...                          ...
# 137843  ChEMBL31.compound.112460
# ...

# %%
CMGC_df.to_csv(path_or_buf='/home/s2861704/ppk/test_kin/prep_storage/K1000_CMGC.csv', sep=',', index=False)

# %%
test_df=pd.read_csv('/home/s2861704/ppk/test_kin/prep_storage/test.csv', sep=',')
display(test_df)
